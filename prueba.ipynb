# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

arr.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr = np.array([[1,2,3],
                [4,5,6]])
arr[0]
# Out:
# array([1, 2, 3])

# %%
arr[0,2]
# Out:
# np.int64(3)
