# %% [markdown]
# # Carga de archivos con pandas
#
# En este notebook veremos cómo cargar archivos CSV, Excel, JSON y datos desde una base de datos SQL usando pandas.

# %%
# Importar librerías necesarias
import pandas as pd

# %% [markdown]
# ## Cargar archivo CSV: Titanic
# Reemplaza 'titanic.csv' por la ruta donde tengas el archivo.

# %%
df_csv = pd.read_csv('titanic.csv')
print(df_csv.head())
df_csv.info()

# %% [markdown]
# ## Cargar archivo Excel: Student Scores
# Reemplaza 'student_scores.xlsx' por la ruta real del archivo.

# %%
# df_excel = pd.read_excel('student_scores.xlsx', sheet_name='Sheet1')
# print(df_excel.head())
# df_excel.info()

# %% [markdown]
# ## 🔹 Cargar archivo JSON (ejemplo)
# Reemplaza 'archivo.json' con tu archivo real.

# %%
# df_json = pd.read_json('archivo.json')
# print(df_json.head())
# df_json.info()

# %% [markdown]
# ## 🔹 Cargar datos desde una base de datos SQL (ejemplo con SQLite)
# Requiere la biblioteca `sqlite3`.

# %%
import sqlite3

# Conexión a la base de datos
# conn = sqlite3.connect('mi_base.db')

# Consulta ejemplo (reemplaza 'mi_tabla' por tu tabla real)
# df_sql = pd.read_sql_query('SELECT * FROM mi_tabla', conn)
# print(df_sql.head())
# df_sql.info()

# Cerrar la conexión
# conn.close()

# %% [markdown]
# ## Ejercicio
# Carga tus propios archivos y revisa:
# - Primeras filas (`.head()`)
# - Tipos de datos (`.dtypes` o `.info()`)
# - Valores nulos (`.isnull().sum()`)
# ¡Practica con tus datasets reales!
